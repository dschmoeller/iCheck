# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import math
import os
import glob
import keras

from PIL import Image
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.optimizers import SGD

# %%
# Load and build raw data structures
equImages = []
equLabels = []
equImagesPath = './testImages/class_a'
for img in os.listdir(equImagesPath):
    i = cv2.imread(equImagesPath + "/" + img)
    iGrey = cv2.cvtColor(i, cv2.COLOR_RGB2GRAY)
    iResized = cv2.resize(iGrey, (64,64))
    equImages.append(iResized)
    equLabels.append(0)    
equX = np.asarray(equImages).reshape((len(equImages), 64, 64, 1)) 
equY = np.asarray(equLabels)

noEquImages = []
noEquLabels = []
noEquImagesPath = './testImages/class_b'
for img in os.listdir(noEquImagesPath):
    i = cv2.imread(noEquImagesPath + "/" + img)
    iGrey = cv2.cvtColor(i, cv2.COLOR_RGB2GRAY)
    iResized = cv2.resize(iGrey, (64,64))
    noEquImages.append(iResized)
    noEquLabels.append(1)    
noEquX = np.asarray(noEquImages).reshape((len(noEquImages), 64, 64, 1)) 
noEquY = np.asarray(noEquLabels)

# Stack the training data 
X = np.vstack((equX, noEquX)) 
X = X/255.0
y = np.hstack((equY, noEquY))

# %%
# Check shapes
print(equX.shape)
print(equY.shape)
print(noEquX.shape)
print(noEquY.shape)
print(X.shape)
print(y.shape)
# Out:
# (124, 64, 64, 1)
# (124,)
# (128, 64, 64, 1)
# (128,)
# (252, 64, 64, 1)
# (252,)

# %%
# Split training and validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=19)

print("Training data:")
print(X_train.shape)
print(y_train.shape)
print("Test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Training data:
# (201, 64, 64, 1)
# (201,)
# Test data:
# (51, 64, 64, 1)
# (51,)

# %%
# Print random samples from training set
n = 20
plt.imshow(X_train[n], cmap='gray')
print(y_train[n])
# Out:
# 0

# %%
# Print random samples from test set
n = 2
plt.imshow(X_test[n], cmap='gray')
print(y_test[n])
# Out:
# 1

# %%
# building a linear stack of layers with the sequential model
model = Sequential()
# convolutional layer with max pooling
model.add(Conv2D(15, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu', input_shape=(64,64,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
# convolutional layer
model.add(Conv2D(5, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# flatten output of conv
model.add(Flatten())
# hidden layer with dropout 
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.2))
# hidden layer with dropout 
model.add(Dense(4, activation='relu'))
model.add(Dropout(0.2))
# output layer
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 15)        150
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 15)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 5)         680
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 5)        0
#  2D)
#
#  flatten (Flatten)           (None, 980)               0
#
#  dense (Dense)               (None, 10)                9810
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 4)                 44
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_2 (Dense)             (None, 2)                 10
#
# =================================================================
# Total params: 10,694
# Trainable params: 10,694
# Non-trainable params: 0
# _________________________________________________________________
# 2022-07-20 07:12:04.661608: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [raw]
# # Build the model
#
# # building a linear stack of layers with the sequential model
# model = Sequential()
# # convolutional layer
# model.add(Conv2D(25, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu', input_shape=(64,64,1)))
# model.add(MaxPooling2D(pool_size=(2,2)))
# # flatten output of conv
# model.add(Flatten())
# # hidden layer
# model.add(Dense(100, activation='relu'))
# # hidden layer
# model.add(Dense(10, activation='relu'))
# # output layer
# model.add(Dense(2, activation='softmax'))
#
# model.summary()

# %% [raw]
# # Build the model
#
# # Model architechture
# model = Sequential()
#
# model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
#
# model.add(Conv2D(16, (3, 3), input_shape=(64, 64, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
#
# model.add(Conv2D(8, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
#
# model.add(Conv2D(4, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
#
#
# model.add(Flatten())
# model.add(Dense(64, activation='relu'))
# model.add(Dropout(0.24))
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.24))
# model.add(Dense(2,activation='softmax'))
#
# model.summary()

# %%
# Train the model 
#opt = SGD(lr=0.01)
opt = "adam"
model.compile(loss = "sparse_categorical_crossentropy", optimizer = opt, metrics=['accuracy'])
history = model.fit(X_train, y_train, batch_size=4, epochs=200, validation_data=(X_test, y_test))


datagen = ImageDataGenerator(
        rotation_range=3, # rotation
        width_shift_range=0.2, # horizontal shift
        height_shift_range=0.2, # vertical shift
        zoom_range=0.2, # zoom
        horizontal_flip=False, # horizontal flip
        brightness_range=[0.2,1.2] # brightness
        )

#history = model.fit(datagen.flow(X_train, y_train, batch_size=16),steps_per_epoch=len(X_train)/16, 
#                     epochs=300, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.7020 - accuracy: 0.5274 - val_loss: 0.6915 - val_accuracy: 0.5882
# Epoch 2/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.6939 - accuracy: 0.5124 - val_loss: 0.6977 - val_accuracy: 0.4118
# Epoch 3/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.6930 - accuracy: 0.5124 - val_loss: 0.6967 - val_accuracy: 0.4118
# Epoch 4/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.6945 - accuracy: 0.4975 - val_loss: 0.6915 - val_accuracy: 0.5490
# Epoch 5/200
# 51/51 [==============================] - 1s 16ms/step - loss: 0.6821 - accuracy: 0.6269 - val_loss: 0.6143 - val_accuracy: 0.7059
# Epoch 6/200
# 51/51 [==============================] - 1s 12ms/step - loss: 0.6342 - accuracy: 0.6617 - val_loss: 0.5208 - val_accuracy: 0.8235
# Epoch 7/200
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5655 - accuracy: 0.6567 - val_loss: 0.6083 - val_accuracy: 0.6078
# Epoch 8/200
# 51/51 [==============================] - 1s 13ms/step - loss: 0.4833 - accuracy: 0.7612 - val_loss: 0.4232 - val_accuracy: 0.7843
# Epoch 9/200
# 51/51 [==============================] - 1s 15ms/step - loss: 0.4621 - accuracy: 0.7313 - val_loss: 0.4098 - val_accuracy: 0.7843
# Epoch 10/200
# 51/51 [==============================] - 1s 14ms/step - loss: 0.3921 - accuracy: 0.7761 - val_loss: 0.4004 - val_accuracy: 0.8235
# Epoch 11/200
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4111 - accuracy: 0.7861 - val_loss: 0.3920 - val_accuracy: 0.8039
# Epoch 12/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.3784 - accuracy: 0.7861 - val_loss: 0.3846 - val_accuracy: 0.8235
# Epoch 13/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.3515 - accuracy: 0.7861 - val_loss: 0.4841 - val_accuracy: 0.7647
# Epoch 14/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.3252 - accuracy: 0.8657 - val_loss: 0.3493 - val_accuracy: 0.8235
# Epoch 15/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.2844 - accuracy: 0.8706 - val_loss: 0.3819 - val_accuracy: 0.8431
# Epoch 16/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.3006 - accuracy: 0.8756 - val_loss: 0.3349 - val_accuracy: 0.8235
# Epoch 17/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2838 - accuracy: 0.8905 - val_loss: 0.3120 - val_accuracy: 0.8431
# Epoch 18/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.
200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.7674 - val_accuracy: 0.8627
# Epoch 176/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0313 - accuracy: 0.9950 - val_loss: 0.8099 - val_accuracy: 0.8627
# Epoch 177/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 0.9900 - val_loss: 0.8301 - val_accuracy: 0.8824
# Epoch 178/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0522 - accuracy: 0.9851 - val_loss: 0.8399 - val_accuracy: 0.8627
# Epoch 179/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.8744 - val_accuracy: 0.8627
# Epoch 180/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0629 - accuracy: 0.9851 - val_loss: 0.8858 - val_accuracy: 0.8627
# Epoch 181/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.8982 - val_accuracy: 0.8627
# Epoch 182/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0395 - accuracy: 0.9900 - val_loss: 0.9161 - val_accuracy: 0.8627
# Epoch 183/200
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0662 - accuracy: 0.9851 - val_loss: 0.8662 - val_accuracy: 0.8627
# Epoch 184/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0366 - accuracy: 0.9950 - val_loss: 0.7218 - val_accuracy: 0.8824
# Epoch 185/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0471 - accuracy: 0.9851 - val_loss: 0.6559 - val_accuracy: 0.8824
# Epoch 186/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0387 - accuracy: 0.9900 - val_loss: 0.5973 - val_accuracy: 0.8431
# Epoch 187/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0266 - accuracy: 0.9950 - val_loss: 0.6802 - val_accuracy: 0.8431
# Epoch 188/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0444 - accuracy: 0.9900 - val_loss: 0.8087 - val_accuracy: 0.8627
# Epoch 189/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0374 - accuracy: 0.9900 - val_loss: 0.8778 - val_accuracy: 0.8627
# Epoch 190/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0259 - accuracy: 0.9950 - val_loss: 0.8074 - val_accuracy: 0.8627
# Epoch 191/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0447 - accuracy: 0.9900 - val_loss: 0.8131 - val_accuracy: 0.8627
# Epoch 192/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0571 - accuracy: 0.9851 - val_loss: 0.8391 - val_accuracy: 0.8627
# Epoch 193/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0600 - accuracy: 0.9851 - val_loss: 0.8497 - val_accuracy: 0.8627
# Epoch 194/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0347 - accuracy: 0.9900 - val_loss: 0.8596 - val_accuracy: 0.8627
# Epoch 195/200
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0628 - accuracy: 0.9801 - val_loss: 0.8675 - val_accuracy: 0.8627
# Epoch 196/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0259 - accuracy: 0.9950 - val_loss: 0.8780 - val_accuracy: 0.8627
# Epoch 197/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0305 - accuracy: 0.9950 - val_loss: 0.8889 - val_accuracy: 0.8627
# Epoch 198/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.9017 - val_accuracy: 0.8627
# Epoch 199/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0375 - accuracy: 0.9900 - val_loss: 0.9204 - val_accuracy: 0.8627
# Epoch 200/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 0.9374 - val_accuracy: 0.8627

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Use the model to make predictions
n = 23
plt.imshow(X_train[n], cmap='gray')
print(y_train[n])
sample = X_train[n].reshape(1,64,64,1)

prediction = model.predict(sample)
print(prediction)
# Out:
# 0
# 1/1 [==============================] - 0s 21ms/step
# [[9.9995983e-01 4.0170966e-05]]

# %%
# Use the model to make predictions on the test test
n = 2
plt.imshow(X_test[n], cmap='gray')
print(y_test[n])
sample = X_test[n].reshape(1,64,64,1)
print(sample.shape)
prediction = model.predict(sample)
print(prediction)
# Out:
# 1
# (1, 64, 64, 1)
# 1/1 [==============================] - 0s 24ms/step
# [[0. 1.]]

# %%
# Save the model 
#history.model.save('equationClassifier.h5')
history.model.save('XXXequationClassifier.h5')
